# %%
from tkinter import *
from tkinter import filedialog
import pandas as pd
import numpy as np
from tkinter import messagebox
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
import matplotlib
import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression


root = Tk()
root.title('Project')
root.geometry('500x500')
root.maxsize(500,500)
root.minsize(500,500)


def load_data():
    global z_
    z_ = filedialog.askopenfilename()
    
    if z_ == '':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must load data!!!!!!!')
        label1.pack()
        win_error.mainloop()
        
    
    global data 
    data = pd.read_csv(z_)
    global x
    x = data.iloc[:,:-1]
    global y 
    y = data.iloc[:,-1]
    
    
def start_RFE():
    global z_
    if z_ == '':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must load data!!!!!!!')
        label1.pack()
        win_error.mainloop()
    if e1.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill RFE!!!!!!!')
        label1.pack()
        win_error.mainloop()
        
    
    model = svm.SVC(kernel='linear')
    rfe = RFE(model,n_features_to_select=int(e1.get()))
    rfe.fit(x,y)
    Filter = rfe.support_
    print(Filter)
    ranking = rfe.ranking_
    print(ranking)
    
    data = x[x.columns[Filter]]
    print(data.shape)
    data['outcome'] = y 
    global newdata
    newdata = data.to_csv("C:\\Users\\20109\\E_elnhas\\newdata.csv",index=False)
    



def svm_():
    if e2.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill test size!!!!!!!')
        label1.pack()
        win_error.mainloop()
    


              
    global c_data
    c_data = pd.read_csv("C:\\Users\\20109\\E_elnhas\\newdata.csv")
    global w
    global z
    w = c_data.iloc[:,:-1]
    z = c_data.iloc[:,-1]
    from sklearn.model_selection import train_test_split
    global x_test
    global x_train
    global y_test
    global y_train
    x_train,x_test,y_train,y_test = train_test_split(w,z,test_size=float(e2.get()),random_state=42)
    global clf
    clf = SVC(kernel=str((li1.get(ACTIVE))))
    clf = clf.fit(x_train,y_train)
    messagebox.showinfo("message", "done")
    
    
def KNN_():
    if e7.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill k_value!!!!!!!')
        label1.pack()
        win_error.mainloop()
       
    if e8.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill test_size!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
    global data
    data = pd.read_csv("C:\\Users\\20109\\E_elnhas\\newdata.csv")
    global w
    global z
    w = data.iloc[:,:-1]
    z = data.iloc[:,-1]
    from sklearn.model_selection import train_test_split
    global x_test
    global x_train
    global y_test
    global y_train
    x_train,x_test,y_train,y_test = train_test_split(w,z,test_size=float(e8.get()),random_state=42)
    global knn_
    knn_ = KNeighborsClassifier(n_neighbors=int(e7.get()))
    knn_ = knn_.fit(x_train,y_train)
    messagebox.showinfo("message", "done")
    
    
def DT_():
    if e5.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill Criterian!!!!!!!')
        label1.pack()
        win_error.mainloop()
       
    if e6.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill Max_Depth!!!!!!!')
        label1.pack()
        win_error.mainloop()
        
    if e9.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must fill test_size!!!!!!!')
        label1.pack()
        win_error.mainloop()
        
        
    global t_data
    t_data = pd.read_csv("C:\\Users\\20109\\E_elnhas\\newdata.csv")
    global w
    global z
    w = t_data.iloc[:,:-1]
    z = t_data.iloc[:,-1]
    from sklearn.model_selection import train_test_split
    global x_test
    global x_train
    global y_test
    global y_train
    x_train,x_test,y_train,y_test = train_test_split(w,z,test_size=float(e9.get()),random_state=42)
    global dt
    dt = DecisionTreeClassifier(criterion=e5.get(),max_depth=int(e6.get()))
    dt = dt.fit(x_train,y_train)
    messagebox.showinfo("message", "done")

def tree_plot():
    if e9.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label2 = Label(win_error,text='You must fill test size!!!!!!!')
        label2.pack()
        win_error.mainloop()
    
    plt.figure(figsize=(5,5))

    #tree.plot_tree(dt,fontsize  = 6)

    plt.savefig('tree_high_dpi',dpi=100)
    from tkinter import ttk
    lal_plot = Label(tree.plot_tree(dt,fontsize  = 6))
    lal_plot.pack()
    lal_plot.place(x= 100,y=270)
    lal_plot=ttk.Treeview(root)

    
def lr():
    if e10.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        win_error.config(background='red')
        label1 = Label(win_error,text='You must fill observation_count!!!!!!!')
        label1.pack()
        win_error.mainloop()
       
    if e11.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        win_error.config(background='red')
        label1 = Label(win_error,text='You must fill Stop!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
    if e12.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        win_error.config(background='red')
        label1 = Label(win_error,text='You must fill test_size!!!!!!!')
        label1.pack()
        win_error.mainloop()   
    
    x_var = np.linspace(start =0,stop = int(e11.get()),num=int(e10.get()) )
    np.random.seed(22)
    y_var = x_var + np.random.normal(size = int(e10.get()) ,loc = 1,scale = 2)
    sns.scatterplot(x=x_var,y=y_var)
    x_var = x_var.reshape(-1,1)
    
    global x_train
    global y_train
    global x_test
    global y_test
    
    x_train,x_test,y_train,y_test = train_test_split(x_var,y_var,test_size=float(e12.get()),random_state=42)
    global LR
    LR = LinearRegression()
    LR = LR.fit(x_train,y_train)
    messagebox.showinfo("message", "done")
    
        
    
    
def test_():   # test of SVM
    if e2.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must train first!!!!!!!')
        label1.pack()
        win_error.mainloop()
        
    try:
        
        from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
        y_pred = clf.predict(x_test)
        a=accuracy_score( y_test, y_pred)
        x=str(a);
        l1 = Label(text='accuracy_score'+x,font=('Roboto',10))
        l1.pack()
        l1.place(x= 170,y=360)
        p=precision_score( y_test, y_pred)
        w=str(p)
        l2 = Label(text='precision_score'+' '+w,font=('Roboto',10))
        l2.pack()
        l2.place(x= 170,y=380)
    
        r=recall_score( y_test, y_pred)
        z=str(r)
        l3 = Label(text='recall_score'+z,font=('Roboto',10))
        l3.pack()
        l3.place(x= 170,y=400)
    
        f= f1_score(y_test, y_pred)
        f1 = str(f)
        l4 = Label(text='f1_score'+f1,font=('Roboto',10))
        l4.pack()
        l4.place(x=170,y=420)
    except NameError:
         messagebox.showinfo("message", "you must train first")
    
            
def test2_():  # test of KNN
    
        if e7.get() == '' or e8.get() == '':
            win_error = Tk()
            win_error.title('Error')
            win_error.geometry('200x100')
            label1 = Label(win_error,text='You must train first!!!!!!!')
            label1.pack()
            win_error.mainloop()
            
            
        try:

            y_pred = knn_.predict(x_test)

            a=accuracy_score( y_test, y_pred)
            x=str(a);
            l1 = Label(text='accuracy_score'+x)
            l1.pack()
            l1.place(x= 100,y=270)
            p=precision_score( y_test, y_pred)
            w=str(p)
            l2 = Label(text='precision_score'+' '+w)
            l2.pack()
            l2.place(x= 100,y=300)

            r=recall_score( y_test, y_pred)
            z=str(r)
            l3 = Label(text='recall_score'+z)
            l3.pack()
            l3.place(x= 100,y=330)
            global error
            error = []
            for i in range(1,40):
                knn = KNeighborsClassifier(n_neighbors=i)
                kn = knn_.fit(x_train,y_train)
                predict_i = knn_.predict(x_test)
                error.append(np.mean(predict_i != y_test))
            er_ind=error.index(min(error))+1;
            er_ind_=str(er_ind)
            er=min(error)
            er_=str(min(error))
            l_er = Label(text='minimum error'+er_+' '+'at k'+' '+er_ind_)
            l_er.pack()
            l_er.place(x= 100,y=360)
        except NameError:
            messagebox.showinfo("message", "you must train first")
        
            
    
def test3_():   #DT
    
    if e5.get() == '' or e6.get() == '' or e9.get() == '':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must train first!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
    try:
    
        y_predict = dt.predict(x_test)
        a=accuracy_score( y_test, y_predict)
        x=str(a);
        l1 = Label(text='accuracy_score'+x,font=('Roboto',15))
        l1.pack()
        l1.place(x= 100,y=270)
        p=precision_score( y_test, y_predict)
        w=str(p)
        l2 = Label(text='precision_score'+' '+w,font=('Roboto',15))
        l2.pack()
        l2.place(x= 100,y=300)
        
        r=recall_score( y_test, y_predict)
        z=str(r)
        l3 = Label(text='recall_score'+z,font=('Roboto',15))
        l3.pack()
        l3.place(x= 100,y=330)
        
        f= f1_score(y_test, y_predict)
        f1 = str(f)
        l4 = Label(text='f1_score'+f1,font=('Roboto',15))
        l4.pack()
        l4.place(x=100,y=360)
    except NameError:
         messagebox.showinfo("message", "you must train first")
        

        
def test4(): # test of linear_regression
    if e10.get() == '' or e11.get() == '' or e12.get() == '':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must preprocess first!!!!!!!')
        label1.pack()
        win_error.mainloop()
    try:
        y_predi = LR.predict(x_test)
        mse = mean_squared_error(y_test,y_predi)
        x=str(mse);
        l1 = Label(text='Mean Square Error'+x)
        l1.pack()
        l1.place(x= 100,y=350)           
    except NameError:
        messagebox.showinfo("message", "you must train first")         
        
    
def secondPage():  #RFE
    fr2 = Frame()
    fr2.place(x=0,y=0,width=500,height=500)
    
    label1 = Label(fr2,text="Data Preprocessing",font=('Roboto',15))
    label1.place(x=50,y=50)
    load_btn = Button(fr2,text='load data',command=load_data,font=('Roboto',15),bg='#F08080',fg='white')
    load_btn.place(x=250,y=50)
    
    label2 = Label(fr2,text="RFE",font=('Roboto',15))
    label2.place(x=100,y=130)
    global e1 
    e1 = Entry(fr2)
    e1.place(x=200,y=140)
    
    startRFE = Button(fr2,text='Start RFE',command=start_RFE,font=('Roboto',15),bg='#F08080',fg='white')
    startRFE.place(x= 150,y=200)
    
    svm_btn = Button(fr2,text='SVM',command=fourth_page,font=('Roboto',15),bg='#F08080',fg='white')
    svm_btn.place(x= 50,y=300)
    
    DT_btn = Button(fr2,text='Decision Tree',command=sixth_page,font=('Roboto',15),bg='#F08080',fg='white')
    DT_btn.place(x= 140,y=300)
    
    KNN_btn = Button(fr2,text='KNN',font=('Roboto',15),command=fifth_page,bg='#F08080',fg='white')
    KNN_btn.place(x= 300,y=300)
    linear_regression_btn = Button(fr2,text='Linear Regression',font=('Roboto',15),command=seventh_page,bg='#F08080',fg='white')
    linear_regression_btn.place(x= 140,y=400)

def fourth_page():  #SVM
    if e1.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must preprocess first!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
    fr4 = Frame()
    fr4.place(x=0,y=0,width=500,height=500)
    label3 = Label(fr4,text="test size",font=('Roboto',15))
    label3.place(x=50,y=160)
    global e2 
    e2 = Entry(fr4)
    e2.place(x=130,y=170)
    l1=Label(fr4,text="kernal type",font=('Roboto',15))
    l1.place(x=50,y=8)
    global li1
    li1=Listbox(fr4,width=30,height=2)
    li1.place(x=250,y=125)
    li1.insert(1,"linear")
    li1.insert(2,"rbf")
    li1.pack()
    start_tr = Button(fr4,text='train',command=svm_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_tr.place(x= 70,y=300)
    test_1 = Button(fr4,text='test',command=test_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    test_1.place(x= 320,y=300)
    messagebox.showinfo("message", "please choose kernal type")
    
    back_btn = Button(fr4,text='back',font=('Roboto',15),command=secondPage,bg='#F08080',fg='white')
    back_btn.place(x= 10,y=450)

def fifth_page():   #KNN
    
    if e1.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must preprocess first!!!!!!!')
        label1.pack()
        win_error.mainloop()
       
    fr5 = Frame()
    fr5.place(x=0,y=0,width=500,height=500)
    lbl_=Label(fr5,text='Welcom in KNN' ,font=100)
    lbl_.place(x=200,y=30)
    
    label5 = Label(fr5,text="K_value",font=('Roboto',15))
    label5.place(x=100,y=70)
    global e7 
    e7 = Entry(fr5)
    e7.place(x=200,y=80)
    
    label_6 = Label(fr5,text="Test_size",font=('Roboto',15))
    label_6.place(x=100,y=120)
    global e8 
    e8 = Entry(fr5)
    e8.place(x=200,y=130)
    
    start_tr = Button(fr5,text='train',command= KNN_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_tr.place(x=100,y=170)
    
    start_test = Button(fr5,text='test',command=test2_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_test.place(x=250,y=170)
    back_btn = Button(fr5,text='back',font=('Roboto',15),command=secondPage,bg='#F08080',fg='white')
    back_btn.place(x= 10,y=450)
    
def sixth_page():   #DT
    
    if e1.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must preprocess first!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
    fr6=Frame()
    fr6.place(x=0,y=0,width=500,height=500)
    lbl_1=Label(fr6,text='Welcom in Decision Tree' ,font=100)
    lbl_1.place(x=150,y=30)
    
    
    
    label5 = Label(fr6,text="Criterian",font=('Roboto',15))
    label5.place(x=100,y=70)
    global e5 
    e5 = Entry(fr6)
    e5.place(x=200,y=80)
    
    label6 = Label(fr6,text="Max_Depth",font=('Roboto',15))
    label6.place(x=80,y=120)
    global e6 
    e6 = Entry(fr6)
    e6.place(x=200,y=130)
    
    label7 = Label(fr6,text="test_size",font=('Roboto',15))
    label7.place(x=100,y=170)
    global e9 
    e9 = Entry(fr6)
    e9.place(x=200,y=180)
    
    start_tr = Button(fr6,text='train',command=DT_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_tr.place(x=100,y=220)
    
    start_test = Button(fr6,text='test',command=test3_,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_test.place(x=250,y=220)
    
    
    plot = Button(fr6,text='plot',command=tree_plot,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    plot.place(x= 400,y=220)
    
    
    back_btn = Button(fr6,text='back',font=('Roboto',15),command=secondPage,bg='#F08080',fg='white')
    back_btn.place(x= 10,y=450)
    

def seventh_page():   #linear regression
    
    if e1.get() =='':
        win_error = Tk()
        win_error.title('Error')
        win_error.geometry('200x100')
        label1 = Label(win_error,text='You must train first!!!!!!!')
        label1.pack()
        win_error.mainloop()
    
       
    fr7 = Frame(background='#ffdbe0')
    fr7.place(x=0,y=0,width=500,height=500)
    lbl_=Label(fr7,text='Welcom in Linear Regression' ,font=100)
    lbl_.place(x=100,y=30)
    
    label5 = Label(fr7,text="observation_count",font=('Roboto',15))
    label5.place(x=100,y=70)
    global e10
    e10 = Entry(fr7)
    e10.place(x=300,y=70)
    label6 = Label(fr7,text="Stop",font=('Roboto',15))
    label6.place(x=100,y=120)
    global e11 
    e11 = Entry(fr7)
    e11.place(x=200,y=120)
        
    label_6 = Label(fr7,text="Test_size",font=('Roboto',15))
    label_6.place(x=100,y=170)
    global e12
    e12 = Entry(fr7)
    e12.place(x=200,y=170)
    
    start_tr = Button(fr7,text='train',command= lr,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_tr.place(x=100,y=270)
    
    start_test = Button(fr7,text='test',command=test4,font=('Roboto',15),bg='#F08080',fg='white',width=10,height=1)
    start_test.place(x=250,y=270)
    back_btn = Button(fr7,text='back',font=('Roboto',15),command=secondPage,bg='#F08080',fg='white')
    back_btn.place(x= 10,y=450)
    
    
    
    
    
fr1 = Frame(root)
button1 = Button(fr1,text='Classification',command=secondPage,font=('Roboto',15),bg='#F08080',fg='white')
button1.pack(side=TOP)
fr1.pack(expand=True)


    


root.mainloop()
# Out:
# [ True  True  True  True  True  True  True  True]
# [1 1 1 1 1 1 1 1]
# (768, 8)
